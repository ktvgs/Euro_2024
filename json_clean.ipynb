# %%
import pandas as pd

# %%
import json

# Specify the correct encoding (usually 'utf-8')
json_file = 'player_stats_merge1.json'

with open(json_file, 'r', encoding='utf-8') as file:
    try:
        data = json.load(file)
        df = pd.DataFrame(data)
        print(df)
    except json.JSONDecodeError as e:
        print(f"Invalid JSON format: {e}")
    except UnicodeDecodeError as e:
        print(f"Unicode decoding error: {e}")
# Out:
#          get                                       parameters errors  results  \
# 0    players   {'league': '4', 'page': '2', 'season': '2024'}     []       20
# 1    players  {'league': '4', 'page': '27', 'season': '2024'}     []       20
# 2    players  {'league': '4', 'page': '11', 'season': '2024'}     []       20
# 3    players   {'league': '4', 'page': '3', 'season': '2024'}     []       20
# 4    players  {'league': '4', 'page': '25', 'season': '2024'}     []       20
# ..       ...                                              ...    ...      ...
# 123  players                {'league': '4', 'season': '2024'}     []       20
# 124  players                {'league': '4', 'season': '2024'}     []       20
# 125  players                {'league': '4', 'season': '2024'}     []       20
# 126  players                {'league': '4', 'season': '2024'}     []       20
# 127  players                {'league': '4', 'season': '2024'}     []       20
#
#                            paging  \
# 0     {'current': 2, 'total': 32}
# 1    {'current': 27, 'total': 32}
# 2    {'current': 11, 'total': 32}
# 3     {'current': 3, 'total': 32}
# 4    {'current': 25, 'total': 32}
# ..                            ...
# 123   {'current': 1, 'total': 32}
# 124   {'current': 1, 'total': 32}
# 125   {'current': 1, 'total': 32}
# 126   {'current': 1, 'total': 32}
# 127   {'current': 1, 'total': 32}
#
#                                               response
# 0    [{'player': {'id': 2332, 'name': 'A. Fiola', '...
# 1    [{'player': {'id': 340, 'name': 'S. Babić', 'f...
# 2    [{'player': {'id': 130, 'name': 'Nélson Semedo...
# 3    [{'player': {'id': 676, 'name': 'V. Bondar', '...
# 4    [{'player': {'id': 579, 'name': 'A. Živković',...
# ..                                                 ...
# 123  [{'player': {'id': 272, 'name': 'A. Rabiot', '...
# 124  [{'player': {'id': 272, 'name': 'A. Rabiot', '...
# 125  [{'player': {'id': 272, 'name': 'A. Rabiot', '...
# 126  [{'player': {'id': 272, 'name': 'A. Rabiot', '...
# 127  [{'player': {'id': 272, 'name': 'A. Rabiot', '...
#
# [128 rows x 6 columns]

# %%
import pandas as pd

# Assuming df is already loaded with data and has a 'response' column

all_players_stats = []  # This will store the flattened data for all players across all rows

# Iterate over each row in the DataFrame
for row in df['response']:
    # Iterate over each player dictionary in the list of players for this row
    for i in row:
        players = {}  # Dictionary to store flattened player data

        # Flatten player details
        for j in i['player'].keys():
            players[j] = i['player'][j]
        
        # Flatten statistics details (assuming there might be multiple statistics entries, but we'll use the first one for simplicity)
        for k in i['statistics'][0].keys():
            if isinstance(i['statistics'][0][k], dict):
                for l in i['statistics'][0][k].keys():
                    players[k+'_'+l] = i['statistics'][0][k][l]
            else:
                players[k] = i['statistics'][0][k]

        # Append the flattened data to the list
        all_players_stats.append(players)

# %%
# Convert the list of player dictionaries to a DataFrame
players_df = pd.DataFrame(all_players_stats)

# Display the resulting DataFrame
players_df.head()
# Out:
#       id        name     firstname lastname  age  \
# 0   2332    A. Fiola  Attila Csaba    Fiola   34
# 1   7398    B. Varga      Barnabás    Varga   30
# 2   7598    P. Pentz       Patrick    Pentz   27
# 3  25343  P. Pekarík         Peter  Pekarík   38
# 4  28322   D. Dibusz         Dénes   Dibusz   34
#
#                                                birth nationality  height  \
# 0  {'date': '1990-02-17', 'place': 'Szekszárd', '...     Hungary  182 cm
# 1  {'date': '1994-10-25', 'place': 'Szombathely',...     Hungary  181 cm
# 2  {'date': '1997-01-02', 'place': 'Salzburg', 'c...     Austria  183 cm
# 3  {'date': '1986-10-30', 'place': 'Žilina', 'cou...    Slovakia  177 cm
# 4  {'date': '1990-11-16', 'place': 'Pécs', 'count...     Hungary  188 cm
#
#   weight  injured  ... fouls_drawn  fouls_committed cards_yellow  \
# 0  70 kg    False  ...         3.0              5.0          0.0
# 1  74 kg    False  ...         4.0              2.0          1.0
# 2  80 kg    False  ...         1.0              NaN          0.0
# 3  73 kg    False  ...         2.0              3.0          1.0
# 4  81 kg    False  ...         NaN              NaN          0.0
#
#   cards_yellowred  cards_red penalty_won penalty_commited penalty_scored  \
# 0             0.0        0.0        None             None            0.0
# 1             0.0        0.0        None             None            0.0
# 2             0.0        0.0        None             None            0.0
# 3             0.0        0.0        None             None            0.0
# 4             0.0        0.0        None             None            0.0
#
#   penalty_missed  penalty_saved
# 0            0.0            NaN
# 1            0.0            NaN
# 2            0.0            0.0
# 3            0.0            NaN
# 4            0.0            0.0
#
# [5 rows x 57 columns]

# %%
# Extract the 'date', 'place', and 'country' from the 'birth' dictionary
players_df['birth_date'] = players_df['birth'].apply(lambda x: x.get('date') if isinstance(x, dict) else None)
players_df['birth_place'] = players_df['birth'].apply(lambda x: x.get('place') if isinstance(x, dict) else None)
players_df['birth_country'] = players_df['birth'].apply(lambda x: x.get('country') if isinstance(x, dict) else None)

# Drop the original 'birth' column
players_df.drop(columns=['birth'], inplace=True)

# Display the resulting DataFrame
players_df.head()
# Out:
#       id        name     firstname lastname  age nationality  height weight  \
# 0   2332    A. Fiola  Attila Csaba    Fiola   34     Hungary  182 cm  70 kg
# 1   7398    B. Varga      Barnabás    Varga   30     Hungary  181 cm  74 kg
# 2   7598    P. Pentz       Patrick    Pentz   27     Austria  183 cm  80 kg
# 3  25343  P. Pekarík         Peter  Pekarík   38    Slovakia  177 cm  73 kg
# 4  28322   D. Dibusz         Dénes   Dibusz   34     Hungary  188 cm  81 kg
#
#    injured                                              photo  ...  \
# 0    False  https://media.api-sports.io/football/players/2...  ...
# 1    False  https://media.api-sports.io/football/players/7...  ...
# 2    False  https://media.api-sports.io/football/players/7...  ...
# 3    False  https://media.api-sports.io/football/players/2...  ...
# 4    False  https://media.api-sports.io/football/players/2...  ...
#
#    cards_yellowred cards_red penalty_won  penalty_commited penalty_scored  \
# 0              0.0       0.0        None              None            0.0
# 1              0.0       0.0        None              None            0.0
# 2              0.0       0.0        None              None            0.0
# 3              0.0       0.0        None              None            0.0
# 4              0.0       0.0        None              None            0.0
#
#   penalty_missed penalty_saved  birth_date  birth_place  birth_country
# 0            0.0           NaN  1990-02-17    Szekszárd        Hungary
# 1            0.0           NaN  1994-10-25  Szombathely        Hungary
# 2            0.0           0.0  1997-01-02     Salzburg        Austria
# 3            0.0           NaN  1986-10-30       Žilina       Slovakia
# 4            0.0           0.0  1990-11-16         Pécs        Hungary
#
# [5 rows x 59 columns]

# %%
players_df.shape
# Out:
# (2532, 59)

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2532 entries, 0 to 2531
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2532 non-null   int64
#  1   name                   2532 non-null   object
#  2   firstname              2532 non-null   object
#  3   lastname               2532 non-null   object
#  4   age                    2532 non-null   int64
#  5   nationality            2532 non-null   object
#  6   height                 2532 non-null   object
#  7   weight                 2526 non-null   object
#  8   injured                2532 non-null   bool
#  9   photo                  2532 non-null   object
#  10  team_id                2532 non-null   int64
#  11  team_name              2532 non-null   object
#  12  team_logo              2532 non-null   object
#  13  league_id              2532 non-null   int64
#  14  league_name            2532 non-null   object
#  15  league_country         2532 non-null   object
#  16  league_logo            2532 non-null   object
#  17  league_flag            0 non-null      object
#  18  league_season          2532 non-null   int64
#  19  games_appearences      2466 non-null   float64
#  20  games_lineups          2466 non-null   float64
#  21  games_minutes          2466 non-null   float64
#  22  games_number           0 non-null      object
#  23  games_position         2532 non-null   object
#  24  games_rating           1794 non-null   object
#  25  games_captain          2532 non-null   bool
#  26  substitutes_in         2466 non-null   float64
#  27  substitutes_out        2466 non-null   float64
#  28  substitutes_bench      2466 non-null   float64
#  29  shots_total            1106 non-null   float64
#  30  shots_on               798 non-null    float64
#  31  goals_total            2466 non-null   float64
#  32  goals_conceded         2456 non-null   float64
#  33  goals_assists          1818 non-null   float64
#  34  goals_saves            58 non-null     float64
#  35  passes_total           1804 non-null   float64
#  36  passes_key             1100 non-null   float64
#  37  passes_accuracy        1798 non-null   float64
#  38  tackles_total          1310 non-null   float64
#  39  tackles_blocks         496 non-null    float64
#  40  tackles_interceptions  930 non-null    float64
#  41  duels_total            1758 non-null   float64
#  42  duels_won              1660 non-null   float64
#  43  dribbles_attempts      1264 non-null   float64
#  44  dribbles_success       998 non-null    float64
#  45  dribbles_past          0 non-null      object
#  46  fouls_drawn            1326 non-null   float64
#  47  fouls_committed        1316 non-null   float64
#  48  cards_yellow           2466 non-null   float64
#  49  cards_yellowred        2466 non-null   float64
#  50  cards_red              2466 non-null   float64
#  51  penalty_won            0 non-null      object
#  52  penalty_commited       0 non-null      object
#  53  penalty_scored         2456 non-null   float64
#  54  penalty_missed         2456 non-null   float64
#  55  penalty_saved          208 non-null    float64
#  56  birth_date             2532 non-null   object
#  57  birth_place            2524 non-null   object
#  58  birth_country          2532 non-null   object
# dtypes: bool(2), float64(30), int64(5), object(22)
# memory usage: 1.1+ MB

# %%
# players_df.to_csv('euro_player_stats.csv',index=False)

# %%
players_df.isna().sum()
# Out:
# id                          0
# name                        0
# firstname                   0
# lastname                    0
# age                         0
# nationality                 0
# height                      0
# weight                      6
# injured                     0
# photo                       0
# team_id                     0
# team_name                   0
# team_logo                   0
# league_id                   0
# league_name                 0
# league_country              0
# league_logo                 0
# league_flag              2532
# league_season               0
# games_appearences          66
# games_lineups              66
# games_minutes              66
# games_number             2532
# games_position              0
# games_rating              738
# games_captain               0
# substitutes_in             66
# substitutes_out            66
# substitutes_bench          66
# shots_total              1426
# shots_on                 1734
# goals_total                66
# goals_conceded             76
# goals_assists             714
# goals_saves              2474
# passes_total              728
# passes_key               1432
# passes_accuracy           734
# tackles_total            1222
# tackles_blocks           2036
# tackles_interceptions    1602
# duels_total               774
# duels_won                 872
# dribbles_attempts        1268
# dribbles_success         1534
# dribbles_past            2532
# fouls_drawn              1206
# fouls_committed          1216
# cards_yellow               66
# cards_yellowred            66
# cards_red                  66
# penalty_won              2532
# penalty_commited         2532
# penalty_scored             76
# penalty_missed             76
# penalty_saved            2324
# birth_date                  0
# birth_place                 8
# birth_country               0
# dtype: int64

# %%
players_df[players_df['id']==752]
# Out:
#        id      name firstname lastname  age nationality  height weight  \
# 322   752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 588   752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 688   752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 728   752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 748   752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# ...   ...       ...       ...      ...  ...         ...     ...    ...
# 2434  752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 2454  752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 2474  752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 2494  752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
# 2514  752  T. Kroos      Toni    Kroos   34     Germany  183 cm  76 kg
#
#       injured                                              photo  ...  \
# 322     False  https://media.api-sports.io/football/players/7...  ...
# 588     False  https://media.api-sports.io/football/players/7...  ...
# 688     False  https://media.api-sports.io/football/players/7...  ...
# 728     False  https://media.api-sports.io/football/players/7...  ...
# 748     False  https://media.api-sports.io/football/players/7...  ...
# ...       ...                                                ...  ...
# 2434    False  https://media.api-sports.io/football/players/7...  ...
# 2454    False  https://media.api-sports.io/football/players/7...  ...
# 2474    False  https://media.api-sports.io/football/players/7...  ...
# 2494    False  https://media.api-sports.io/football/players/7...  ...
# 2514    False  https://media.api-sports.io/football/players/7...  ...
#
#       cards_yellowred cards_red penalty_won  penalty_commited penalty_scored  \
# 322               0.0       0.0        None              None            0.0
# 588               0.0       0.0        None              None            0.0
# 688               0.0       0.0        None              None            0.0
# 728               0.0       0.0        None              None            0.0
# 748               0.0       0.0        None              None            0.0
# ...               ...       ...         ...               ...            ...
# 2434              0.0       0.0        None              None            0.0
# 2454              0.0       0.0        None              None            0.0
# 2474              0.0       0.0        None              None            0.0
# 2494              0.0       0.0        None              None            0.0
# 2514              0.0       0.0        None              None            0.0
#
#      penalty_missed penalty_saved  birth_date  birth_place  birth_country
# 322             0.0           NaN  1990-01-04   Greifswald        Germany
# 588             0.0           NaN  1990-01-04   Greifswald        Germany
# 688             0.0           NaN  1990-01-04   Greifswald        Germany
# 728             0.0           NaN  1990-01-04   Greifswald        Germany
# 748             0.0           NaN  1990-01-04   Greifswald        Germany
# ...             ...           ...         ...          ...            ...
# 2434            0.0           NaN  1990-01-04   Greifswald        Germany
# 2454            0.0           NaN  1990-01-04   Greifswald        Germany
# 2474            0.0           NaN  1990-01-04   Greifswald        Germany
# 2494            0.0           NaN  1990-01-04   Greifswald        Germany
# 2514            0.0           NaN  1990-01-04   Greifswald        Germany
#
# [66 rows x 59 columns]

# %%
euro_players=players_df.drop_duplicates(subset='id',keep='first')
euro_players
# Out:
#          id           name       firstname    lastname  age  nationality  \
# 0      2332       A. Fiola    Attila Csaba       Fiola   34      Hungary
# 1      7398       B. Varga        Barnabás       Varga   30      Hungary
# 2      7598       P. Pentz         Patrick       Pentz   27      Austria
# 3     25343     P. Pekarík           Peter     Pekarík   38     Slovakia
# 4     28322      D. Dibusz           Dénes      Dibusz   34      Hungary
# ..      ...            ...             ...         ...  ...          ...
# 641   41621  Matheus Nunes    Matheus Luiz       Nunes   26     Portugal
# 642   61431      J. Kiwior     Jakub Piotr      Kiwior   24       Poland
# 643  129058  B. Verbruggen            Bart  Verbruggen   22  Netherlands
# 644  130423     B. Gilmour  Billy Clifford     Gilmour   23     Scotland
# 645  157052   R. Calafiori        Riccardo   Calafiori   22        Italy
#
#      height weight  injured  \
# 0    182 cm  70 kg    False
# 1    181 cm  74 kg    False
# 2    183 cm  80 kg    False
# 3    177 cm  73 kg    False
# 4    188 cm  81 kg    False
# ..      ...    ...      ...
# 641  183 cm  78 kg    False
# 642  189 cm  75 kg    False
# 643  193 cm  66 kg    False
# 644  170 cm  60 kg    False
# 645  188 cm  86 kg    False
#
#                                                  photo  ...  cards_yellowred  \
# 0    https://media.api-sports.io/football/players/2...  ...              0.0
# 1    https://media.api-sports.io/football/players/7...  ...              0.0
# 2    https://media.api-sports.io/football/players/7...  ...              0.0
# 3    https://media.api-sports.io/football/players/2...  ...              0.0
# 4    https://media.api-sports.io/football/players/2...  ...              0.0
# ..                                                 ...  ...              ...
# 641  https://media.api-sports.io/football/players/4...  ...              0.0
# 642  https://media.api-sports.io/football/players/6...  ...              0.0
# 643  https://media.api-sports.io/football/players/1...  ...              0.0
# 644  https://media.api-sports.io/football/players/1...  ...              0.0
# 645  https://media.api-sports.io/football/players/1...  ...              0.0
#
#     cards_red penalty_won  penalty_commited penalty_scored penalty_missed  \
# 0         0.0        None              None            0.0            0.0
# 1         0.0        None              None            0.0            0.0
# 2         0.0        None              None            0.0            0.0
# 3         0.0        None              None            0.0            0.0
# 4         0.0        None              None            0.0            0.0
# ..        ...         ...               ...            ...            ...
# 641       0.0        None              None            0.0            0.0
# 642       0.0        None              None            0.0            0.0
# 643       0.0        None              None            0.0            0.0
# 644       0.0        None              None            0.0            0.0
# 645       0.0        None              None            0.0            0.0
#
#     penalty_saved  birth_date     birth_place  birth_country
# 0             NaN  1990-02-17       Szekszárd        Hungary
# 1             NaN  1994-10-25     Szombathely        Hungary
# 2             0.0  1997-01-02        Salzburg        Austria
# 3             NaN  1986-10-30          Žilina       Slovakia
# 4             0.0  1990-11-16            Pécs        Hungary
# ..            ...         ...             ...            ...
# 641           NaN  1998-08-27  Rio de Janeiro         Brazil
# 642           NaN  2000-02-15           Tychy         Poland
# 643           0.0  2002-08-18          Zwolle    Netherlands
# 644           NaN  2001-06-11          Irvine       Scotland
# 645           NaN  2002-05-19            Roma          Italy
#
# [626 rows x 59 columns]

# %%
euro_players.to_csv('euro_final.csv',index=False)
